# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os 
import statsmodels.api as sm
from statsmodels.formula.api import ols
from mpl_toolkits.mplot3d import Axes3D

# %%
df = pd.read_excel('childmortality.xlsx')
m = df.dropna()

# %%
mortalidade = m.iloc[0:,[0,208]].dropna()
mortalidade
# Out:
#        Under five mortality   2007
# 0               Afghanistan  113.2
# 1                   Albania   18.7
# 2                   Algeria   30.7
# 3                    Angola  196.4
# 4       Antigua and Barbuda   11.3
# 5                 Argentina   15.8
# 6                   Armenia   21.1
# 7                 Australia    5.4
# 8                   Austria    4.6
# 9                Azerbaijan   45.8
# 10                  Bahamas   14.8
# 11                  Bahrain   10.0
# 12               Bangladesh   59.4
# 13                 Barbados   15.8
# 14                  Belarus    7.9
# 15                  Belgium    4.8
# 16                   Belize   20.6
# 17                    Benin  119.0
# 18                   Bhutan   51.3
# 19                  Bolivia   54.9
# 20   Bosnia and Herzegovina    8.2
# 21                 Botswana   64.0
# 22                   Brazil   19.7
# 23                   Brunei    9.0
# 24                 Bulgaria   14.3
# 25             Burkina Faso  139.9
# ...

# %%
fertility = pd.read_excel('totalfertility.xlsx')
f=fertility.dropna()

# %%
fertility_ano = f.iloc[0:,[0,208]]
fertility_ano
# Out:
#        Total fertility rate  2007
# 0               Afghanistan  6.46
# 1                   Albania  1.80
# 2                   Algeria  2.66
# 3                    Angola  6.52
# 4       Antigua and Barbuda  2.18
# 5                 Argentina  2.25
# 6                   Armenia  1.40
# 7                 Australia  1.92
# 8                   Austria  1.38
# 9                Azerbaijan  1.99
# 10                  Bahamas  1.88
# 11                  Bahrain  2.29
# 12               Bangladesh  2.44
# 13                 Barbados  1.83
# 14                  Belarus  1.39
# 15                  Belgium  1.80
# 16                   Belize  2.97
# 17                    Benin  5.37
# 18                   Bhutan  2.59
# 19                  Bolivia  3.55
# 20   Bosnia and Herzegovina  1.21
# 21                 Botswana  2.91
# 22                   Brazil  1.94
# 23                   Brunei  2.12
# 24                 Bulgaria  1.40
# 25             Burkina Faso  6.12
# ...

# %%
life = pd.read_excel('lifeexpectancy.xlsx')
l = life.dropna()

# %%
life_ano = l.iloc[0:,[0,208]].dropna()
life_ano
# Out:
#             Life expectancy  2007
# 0               Afghanistan  52.4
# 1                   Albania  76.6
# 2                   Algeria  75.3
# 3                    Angola  56.2
# 4       Antigua and Barbuda  75.3
# 5                 Argentina  75.2
# 6                   Armenia  72.3
# 7                 Australia  81.5
# 8                   Austria  80.1
# 9                Azerbaijan  69.1
# 10                  Bahamas  71.8
# 11                  Bahrain  77.0
# 12               Bangladesh  67.7
# 13                 Barbados  75.1
# 14                  Belarus  69.7
# 15                  Belgium  79.5
# 16                   Belize  70.6
# 17                    Benin  59.2
# 18                   Bhutan  70.3
# 19                  Bolivia  70.9
# 20   Bosnia and Herzegovina  77.3
# 21                 Botswana  52.4
# 22                   Brazil  73.0
# 23                   Brunei  76.8
# 24                 Bulgaria  72.9
# 25             Burkina Faso  57.4
# ...

# %%
life_ano['fertility'] = fertility_ano[2007]
life_ano['expectativa']=life_ano[2007]

# %%
life_ano['mortality']=mortalidade[2007]
life_ano
# Out:
#             Life expectancy  2007  fertility  expectativa  mortality
# 0               Afghanistan  52.4       6.46         52.4      113.2
# 1                   Albania  76.6       1.80         76.6       18.7
# 2                   Algeria  75.3       2.66         75.3       30.7
# 3                    Angola  56.2       6.52         56.2      196.4
# 4       Antigua and Barbuda  75.3       2.18         75.3       11.3
# 5                 Argentina  75.2       2.25         75.2       15.8
# 6                   Armenia  72.3       1.40         72.3       21.1
# 7                 Australia  81.5       1.92         81.5        5.4
# 8                   Austria  80.1       1.38         80.1        4.6
# 9                Azerbaijan  69.1       1.99         69.1       45.8
# 10                  Bahamas  71.8       1.88         71.8       14.8
# 11                  Bahrain  77.0       2.29         77.0       10.0
# 12               Bangladesh  67.7       2.44         67.7       59.4
# ...

# %%
x=life_ano[['expectativa','fertility']].copy()
y=life_ano['mortality'].copy()
x=sm.add_constant(x)

# %%
est1=sm.OLS(y,x).fit()
est1.summary()

#life_ano.plot(kind='scatter', x='mortality', y='expectativa')
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:              mortality   R-squared:                       0.871
# Model:                            OLS   Adj. R-squared:                  0.870
# Method:                 Least Squares   F-statistic:                     601.8
# Date:                Fri, 11 Nov 2016   Prob (F-statistic):           6.25e-80
# Time:                        16:28:37   Log-Likelihood:                -759.42
# No. Observations:                 181   AIC:                             1525.
# Df Residuals:                     178   BIC:                             1534.
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                   coef    std err          t      P>|t|      [95.0% Conf. Int.]
# -------------------------------------------------------------------------------
# const         180.6089     17.752     10.174      0.000       145.578   215.639
# ...

# %%
xx1,xx2 = np.meshgrid(np.linspace(x.expectativa.min(),x.expectativa.max(),100),(np.linspace(x.fertility.min(),x.fertility.max(),100)))
z1=est1.params[0]+est1.params[1]*xx1+est1.params[2]*xx2
fig=plt.figure(figsize=(12,8))
ax=Axes3D(fig,azim=-115,elev=15)
surf=ax.plot_surface(xx1,xx2,z1,cmap=plt.cm.RdBu_r,alpha=0.6,linewidth=0)
resid=y-est1.predict(x)
ax.scatter(x[resid>=0].expectativa,x[resid>=0].fertility,y[resid>=0],color='black',alpha=1.0,facecolor='none')
ax.scatter(x[resid<0].expectativa,x[resid<0].fertility,y[resid<0],color='black',alpha=1.0)
ax.set_xlabel('Expectativa de Vida')
ax.set_ylabel('Fertilidade')
ax.set_zlabel('Mortalidade')
